# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Siddiq\Downloads\archive\menu.csv")

# %%
df.dtypes
# Out:
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# Total Fat                        float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# Calcium (% Daily Value)            int64
# ...

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="mydb"
)

# %%
mydb

# %%
mycursor = mydb.cursor()

# %%
mycursor.execute("SELECT * FROM mcdonald")

myresult = mycursor.fetchall()

# %%
sql_data =pd.read_sql_query ("SELECT * FROM mcdonald", mydb)

# %%
df = pd.DataFrame(sql_data)

# %%
df
# Out:
#       id            Category                                           Item  \
# 0      1           Breakfast                                   Egg McMuffin
# 1      2           Breakfast                              Egg White Delight
# 2      3           Breakfast                               Sausage McMuffin
# 3      4           Breakfast                      Sausage McMuffin with Egg
# 4      5           Breakfast               Sausage McMuffin with Egg Whites
# ..   ...                 ...                                            ...
# 255  256  Smoothies & Shakes             McFlurry with Oreo Cookies (Small)
# 256  257  Smoothies & Shakes            McFlurry with Oreo Cookies (Medium)
# 257  258  Smoothies & Shakes             McFlurry with Oreo Cookies (Snack)
# 258  259  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Med
# 259  260  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Sna
#
# ...

# %%
df.dtypes
# Out:
# id                                 int64
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# Total Fat                        float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# ...

# %%
df.describe(include='all')
# Out:
#                 id      Category  \
# count   260.000000           260
# unique         NaN             9
# top            NaN  Coffee & Tea
# freq           NaN            95
# mean    130.500000           NaN
# std      75.199734           NaN
# min       1.000000           NaN
# 25%      65.750000           NaN
# 50%     130.500000           NaN
# 75%     195.250000           NaN
# max     260.000000           NaN
#
#                                                  Item  Serving Size  \
# count                                             260           260
# unique                                            255           107
# top     Nonfat Latte with Sugar Free French Vanilla S  16 fl oz cup
# freq                                                3            45
# mean                                              NaN           NaN
# std                                               NaN           NaN
# min                                               NaN           NaN
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plot = sns.swarmplot(x="Category", y="Sodium",size=2,data=df)
plt.setp(plot.get_xticklabels(),rotation = 70)
plt.title("Sodium")
plt.show()
# Out:
# C:\Users\Siddiq\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df["Sodium"].describe()
# Out:
# count     260.000000
# mean      495.750000
# std       577.026323
# min         0.000000
# 25%       107.500000
# 50%       190.000000
# 75%       865.000000
# max      3600.000000
# Name: Sodium, dtype: float64

# %%
df["Sodium"].idxmax()
# Out:
# 82

# %%
df.at[82,"Item"]
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
plot = sns.jointplot(x="Protein" ,y="Total Fat",data=df)
